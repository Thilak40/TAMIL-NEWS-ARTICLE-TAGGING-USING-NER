# %%
import pandas as pd
import json

with open(r'annotations (2).json', 'r',encoding='utf-8') as f:
    data = json.load(f)

# %%
entity_name=["PER","LOC","DATE","TIME","GPE","EVENT","MONEY","LANGUAGE","LAW","PRODUCT","QUANTITY","WORK_OF_ART","ORG","CARDINAL","FACILITY"]

train_data = data['annotations']
train_data = [tuple(i) for i in train_data]

# %%
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [[0, 15, 'WORK_OF_ART'],
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
for i in train_data:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [(0, 15, 'WORK_OF_ART'),
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
import pandas as pd
import json

with open(r'annotations[1].json', 'r',encoding='utf-8') as f:
    data = json.load(f)

# %%
entity_name=["PER","LOC","DATE","TIME","GPE","EVENT","MONEY","LANGUAGE","LAW","PRODUCT","QUANTITY","WORK_OF_ART","ORG","CARDINAL","FACILITY"]

train_data1 = data['annotations']
train_data1 = [tuple(i) for i in train_data1]

# %%
train_data1
# Out:
# [('பத்து ஆண்டுகளாக புகை பிடிப்பவருக்கு காச நோய் வாய்ப்பு பத்து மடங்கு அதிகம்\tதேனி : பத்து ஆண்டுகளாக தொடர்ந்து புகை பிடித்து வருபவருக்கு, காச நோய் ஏற்படுவதற்கான வாய்ப்பு பத்து மடங்கு அதிகம் என கருத்தரங்கில் தெரிவிக்கப்பட்டது. வளர்ச்சி செயலாக்க குழுமம் மற்றும் பங்குதாரர்கள் சார்பில், உலக காசநோய் தினம் குறித்த கருத்தரங்கம் தேனியில் நடந்தது. திட்ட இயக்குனர் வனஜா தலைமை வகித்தார். தேனி மருத்துவ கல்லூரி ஆஸ்பத்திரி துணை முதல்வர் மைத்ரேயி, சுகாதாரப்பணிகள்(காச நோய்) துணை இயக்குனர் பாலாஜி உட்பட பலர் பங்கேற்றனர். \r',
#   {'entities': [[0, 5, 'CARDINAL'],
#     [16, 35, 'PER'],
#     [54, 59, 'CARDINAL'],
#     [74, 78, 'LOC'],
#     [81, 86, 'CARDINAL'],
#     [222, 247, 'ORG'],
#     [280, 297, 'EVENT'],
#     [353, 357, 'PER'],
#     [375, 396, 'ORG'],
#     [422, 430, 'PER'],
#     [473, 479, 'PER']]}),
# ...

# %%
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
len(train_data1)
# Out:
# 16

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [(0, 15, 'WORK_OF_ART'),
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
len(train_data)
# Out:
# 20

# %%
import pandas as pd
import json

with open(r'annotations_(3)[1].json', 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_name=["PER","LOC","DATE","TIME","GPE","EVENT","MONEY","LANGUAGE","LAW","PRODUCT","QUANTITY","WORK_OF_ART","ORG","CARDINAL","FACILITY"]

train_data1= data['annotations']
train_data1= [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [(0, 15, 'WORK_OF_ART'),
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
import pandas as pd
import json

with open(r'training_data.json', 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_name=["PER","LOC","DATE","TIME","GPE","EVENT","MONEY","LANGUAGE","LAW","PRODUCT","QUANTITY","WORK_OF_ART","ORG","CARDINAL","FACILITY"]

train_data1= data['annotations']
train_data1= [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [(0, 15, 'WORK_OF_ART'),
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
len(train_data)
# Out:
# 41

# %%
import pandas as pd
import json

with open(r'annotations[3].json', 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_name=["PER","LOC","DATE","TIME","GPE","EVENT","MONEY","LANGUAGE","LAW","PRODUCT","QUANTITY","WORK_OF_ART","ORG","CARDINAL","FACILITY"]

train_data1= data['annotations']
train_data1= [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [(0, 15, 'WORK_OF_ART'),
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
import pandas as pd
import json

with open(r'annotations (4).json', 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_name=["PER","LOC","DATE","TIME","GPE","EVENT","MONEY","LANGUAGE","LAW","PRODUCT","QUANTITY","WORK_OF_ART","ORG","CARDINAL","FACILITY"]

train_data1= data['annotations']
train_data1= [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [(0, 15, 'WORK_OF_ART'),
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
import pandas as pd
import json

with open(r'annotations (6).json', 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_name=["PER","LOC","DATE","TIME","GPE","EVENT","MONEY","LANGUAGE","LAW","PRODUCT","QUANTITY","WORK_OF_ART","ORG","CARDINAL","FACILITY"]

train_data1= data['annotations']
train_data1= [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [(0, 15, 'WORK_OF_ART'),
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
import pandas as pd
import json

with open(r'annotations (7).json', 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_name=["PER","LOC","DATE","TIME","GPE","EVENT","MONEY","LANGUAGE","LAW","PRODUCT","QUANTITY","WORK_OF_ART","ORG","CARDINAL","FACILITY"]

train_data1= data['annotations']
train_data1= [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [(0, 15, 'WORK_OF_ART'),
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
import pandas as pd
import json

with open(r'annotations (8).json', 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_name=["PER","LOC","DATE","TIME","GPE","EVENT","MONEY","LANGUAGE","LAW","PRODUCT","QUANTITY","WORK_OF_ART","ORG","CARDINAL","FACILITY"]

train_data1= data['annotations']
train_data1= [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [(0, 15, 'WORK_OF_ART'),
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
import pandas as pd
import json

with open(r'annotations[10].json', 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_name=["PER","LOC","DATE","TIME","GPE","EVENT","MONEY","LANGUAGE","LAW","PRODUCT","QUANTITY","WORK_OF_ART","ORG","CARDINAL","FACILITY"]

train_data1= data['annotations']
train_data1= [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [(0, 15, 'WORK_OF_ART'),
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
len(train_data)
# Out:
# 98

# %%
import pandas as pd
import json

with open(r'annotations_(1)[1].json', 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_name=["PER","LOC","DATE","TIME","GPE","EVENT","MONEY","LANGUAGE","LAW","PRODUCT","QUANTITY","WORK_OF_ART","ORG","CARDINAL","FACILITY"]

train_data1= data['annotations']
train_data1= [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('கருத்து கணிப்பு வெளியிட தடை மாநில தேர்தல் கமிஷன் உத்தரவு\tசென்னை : பிரசாரம் ஓய்ந்த பின்னும், தேர்தல் நாளன்றும் கருத்துக் கணிப்புகளை நடத்தவும், வெளியிடவும் தேர்தல் கமிஷன் தடை விதித்துள்ளது. இது குறித்து தேர்தல் கமிஷன் வெளியிட்டுள்ள செய்திக் குறிப்பு: தேர்தல் விதிகளின்படி, தேர்தல் நாளன்று (27ம் தேதி), ஓட்டு அளித்து விட்டு வெளியே வருபவர்களிடம் கருத்துக் கணிப்பை நடத்துவதும், அதை தேர்தல் முடியும் வரை வெளியிடுவதும் கூடாது. அது போல், தேர்தலுக்கு முந்தைய கருத்துக் கணிப்புகளையும், தேர்தல் பிரசாரம் முடியும் இன்று(25ம் தேதி) மாலை 5 மணி முதல் தேர்தல் நடைபெறும் 27ம் தேதி மாலை 5 மணி வரை வெளியிடக் கூடாது. இது அனைத்து "டிவி\', ரேடியோ, பத்திரிகை, இன்டர்நெட், மொபைல் போன் என எந்த ஊடகங்களுக்கும், அரசு, தனியார் நிறுவனங்களுக்கும் பொருந்தும். மீறுபவர்கள் மீது சட்டப்படி நடவடிக்கை எடுக்கப்படும். இவ்வாறு செய்திக் குறிப்பில் கூறப்பட்டுள்ளது.\r',
#   {'entities': [(0, 15, 'WORK_OF_ART'),
#     [28, 33, 'LOC'],
#     [34, 41, 'EVENT'],
#     [57, 63, 'GPE'],
#     [66, 74, 'EVENT'],
#     [92, 99, 'EVENT'],
# ...

# %%
len(train_data)
# Out:
# 128

# %%
import pandas as pd
import os
from tqdm import tqdm
import spacy
from spacy.tokens import DocBin
nlp = spacy.load("en_core_web_lg") 

db = DocBin() 

for text, annot in tqdm(train_data): 
    doc = nlp.make_doc(text) 
    ents = []
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents 
    db.add(doc)
output_dir=r"C:\Users\Mohamed Kani P K\Desktop\Thilak NLP"
os.chdir(output_dir)
db.to_disk("./train.spacy")
# Out:
#  22%|█████████████████▌                                                              | 28/128 [00:00<00:00, 280.00it/s]
# Skipping entity
# Skipping entity
#  80%|███████████████████████████████████████████████████████████████▌               | 103/128 [00:00<00:00, 211.49it/s]
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# 100%|███████████████████████████████████████████████████████████████████████████████| 128/128 [00:00<00:00, 210.46it/s]

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# [+] Auto-filled config with all values
# [+] Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
import spacy
nlp = spacy.load(r"C:\Users\Mohamed Kani P K\Desktop\Thilak NLP\output\model-best")
# Get input from the user
text = input("Enter the text: ")

# Process the text with the loaded model
doc = nlp(text)

# Render the named entities
spacy.displacy.render(doc, style="ent", jupyter=True)
# Out:
# Enter the text:  நாடு முழுவதும் 21 போலி பல்கலைக்கழகங்கள் : கபில் சிபல் தகவல்	புதுடில்லி : நாடு முழுவதும் அங்கீகாரம் பெறாத 200 கல்வி நிறுவனங்களும், 21 போலி பல்கலைக்கழகங்களும் கண்டறியப்பட்டுள்ளதாக, பார்லிமென்டில் மத்திய அமைச்சர் கபில் சிபல் தெரிவித்தார். போலி பல்கலைக் கழகங் களை ஒழிக்க நடவடிக்கை எடுக்கப்படும் என்றார். மத்திய மனிதவளத்துறை அமைச்சர் கபில் சிபல் நேற்று லோக்சபாவில் கூறியதாவது: அனைத்து இந்திய தொழில்நுட்பக் கல்விக் கழகத்தின் (ஏ.ஐ.சி.டி.இ.,) விதிமுறைகளின்படிதான் நாட்டிலுள்ள தொழில்நுட்ப மற்றும் மேலாண்மை கல்வி நிறுவனங்கள் இயங்கி வருகின்றன. இந்நிலையில், ஏ.ஐ.சி.டி.இ.,யின் அங்கீகாரம் பெறாமல் 201 கல்வி நிறுவனங்கள் நாடு முழுவதும் இயங்கி வருவது கண்டறியப்பட்டுள்ளன. அவற்றில் மகாராஷ்டிராவில் 74, டில்லியில் 24, கர்நாடகாவில் 22, தமிழகத்தில் 19, உத்தரபிரதேசம் மற்றும் மேற்குவங்கத்தில் தலா 13 நிறுவனங்கள் உள்ளன. இவை அனைத்தும் ஏ.ஐ.சி.டி.இ.,யின் ஒழுங்குமுறை நடைமுறைகளை மீறி செயல்படுகின்றன. இவற்றில், ஐதராபாத்தில் உள்ள ஐ.எஸ்.பி., டில்லி, குர்கான் மற்றும் சண்டிகரில் இயங்கி வரும் ஐ.சி.எப்.ஏ.ஐ., பிசினஸ
# ...
